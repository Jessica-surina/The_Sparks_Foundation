# %% [markdown]
# # Problem

# %% [markdown]
# Perform ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’
#
# You are the business owner of the retail firm and want to see how your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data? You can choose any of the tool of your choice (Python/R/Tableau/PowerBI/Excel)
#
# Dataset : https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view?usp=sharing

# %% [markdown]
# # Business Analytics

# %% [markdown]
# Business analytics is the process of collating, sorting, processing, and studying business data, and using statistical models and iterative methodologies to transform data into business insights. The goal of business analytics is to determine which datasets are useful and how they can be leveraged to solve problems and increase efficiency, productivity, and revenue.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing DataSet

# %%
df= pd.read_csv("C:/Users/DELL/Downloads/SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.isnull().sum()  #To find if there are any null values present.
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df['City'].value_counts()[:20]  #top 20 cities
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Name: City, dtype: int64

# %%
df['State'].value_counts()  #states
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Ship Mode'].value_counts() #standard class is preferred the most
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Segment'].value_counts()  #consumer product tops the list
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df[df['Category']=='Furniture']['Sub-Category'].value_counts()  #furnishings tops the list
# Out:
# Furnishings    957
# Chairs         617
# Tables         319
# Bookcases      228
# Name: Sub-Category, dtype: int64

# %%
df[df['Category']=='Technology']['Sub-Category'].value_counts() # phones tops the list
# Out:
# Phones         889
# Accessories    775
# Machines       115
# Copiers         68
# Name: Sub-Category, dtype: int64

# %%
df[df['Category']=='Office Supplies']['Sub-Category'].value_counts()  #binders top the list
# Out:
# Binders       1523
# Paper         1370
# Storage        846
# Art            796
# Appliances     466
# Labels         364
# Envelopes      254
# Fasteners      217
# Supplies       190
# Name: Sub-Category, dtype: int64

# %%
sum(df[df['Category']=='Furniture']['Profit'])
# Out:
# 18451.2728

# %%
sum(df[df['Category']=='Technology']['Profit'])
# Out:
# 145454.9480999999

# %%
sum(df[df['Category']=='Office Supplies']['Profit'])
# Out:
# 122490.80080000011

# %% [markdown]
# Technology has a profit of 145k

# %%
sum(df[df['Category']=='Office Supplies']['Quantity'])
# Out:
# 22906

# %%
sum(df[df['Category']=='Technology']['Quantity'])
# Out:
# 6939

# %%
sum(df[df['Category']=='Furniture']['Quantity'])
# Out:
# 8028

# %% [markdown]
# 22k items were sold of office supply

# %%
df[df['Region']=='East']['Profit'].sum()
# Out:
# 91522.78

# %%
df[df['Region']=='West']['Profit'].sum()
# Out:
# 108418.4489

# %%
df[df['Region']=='Central']['Profit'].sum()
# Out:
# 39706.3625

# %%
df[df['Region']=='South']['Profit'].sum()
# Out:
# 46749.4303

# %% [markdown]
# West region has the highest profit of 108k

# %%
df['Profit'].sum()
# Out:
# 286397.0217

# %%
df['Sales'].sum()
# Out:
# 2297200.8603

# %% [markdown]
# Total sales were 2M

# %%
pd.DataFrame(df.groupby('State').sum())['Profit'].sort_values(ascending=True)
# Out:
# State
# Texas                  -25729.3563
# Ohio                   -16971.3766
# Pennsylvania           -15559.9603
# Illinois               -12607.8870
# North Carolina          -7490.9122
# Colorado                -6527.8579
# Tennessee               -5341.6936
# Arizona                 -3427.9246
# Florida                 -3399.3017
# Oregon                  -1190.4705
# Wyoming                   100.1960
# West Virginia             185.9216
# North Dakota              230.1497
# South Dakota              394.8283
# Maine                     454.4862
# Idaho                     826.7231
# Kansas                    836.4435
# District of Columbia     1059.5893
# New Mexico               1157.1161
# Iowa                     1183.8119
# New Hampshire            1706.5028
# South Carolina           1769.0566
# Montana                  1833.3285
# Nebraska                 2037.0942
# Louisiana                2196.1023
# Vermont                  2244.9783
# ...

# %%
pd.DataFrame(df.groupby('State').sum())['Sales'].sort_values(ascending=True)
# Out:
# State
# North Dakota               919.9100
# West Virginia             1209.8240
# Maine                     1270.5300
# South Dakota              1315.5600
# Wyoming                   1603.1360
# District of Columbia      2865.0200
# Kansas                    2914.3100
# Idaho                     4382.4860
# Iowa                      4579.7600
# New Mexico                4783.5220
# Montana                   5589.3520
# New Hampshire             7292.5240
# Nebraska                  7464.9300
# South Carolina            8481.7100
# Vermont                   8929.3700
# Louisiana                 9217.0300
# Mississippi              10771.3400
# Utah                     11220.0560
# Arkansas                 11678.1300
# Connecticut              13384.3570
# Nevada                   16729.1020
# Oregon                   17431.1500
# Alabama                  19510.6400
# Oklahoma                 19683.3900
# Missouri                 22205.1500
# Rhode Island             22627.9560
# ...

# %% [markdown]
# Highest no of sale was in California and lowest was in North Dakota

# %%
pd.DataFrame(df.groupby('Sub-Category').sum())['Discount'].sort_values(ascending=True)
# Out:
# Sub-Category
# Copiers         11.00
# Supplies        14.60
# Fasteners       17.80
# Envelopes       20.40
# Labels          25.00
# Machines        35.20
# Bookcases       48.14
# Art             59.60
# Accessories     60.80
# Storage         63.20
# Appliances      77.60
# Tables          83.35
# Paper          102.60
# Chairs         105.00
# Furnishings    132.40
# Phones         137.40
# Binders        567.00
# Name: Discount, dtype: float64

# %%
#DISTRIBUTION OF PRODUCTS
plt.figure(figsize=(12,9))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# # Exploratory Data Analysis

# %%
corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,5))
sns.set_style('darkgrid')
abc=df['State'].value_counts()[:10]
sns.barplot(x=abc,y=abc.index,palette='Set1')
plt.title("Top ten states (sales wise)",size=20)
plt.xlabel("Number of orders",size=15)
# Out:
# Text(0.5, 0, 'Number of orders')

# %%
sns.set_context("poster", font_scale = 0.6, rc={"grid.linewidth": 5})
sns.set_style('darkgrid')
sns.catplot(x='Region', data=df,kind='count',height=4,aspect=1.5,palette='husl',).set_axis_labels('region of shipping',
                                                                                                      'No. of orders')

# %%
plt.figure(figsize=(12,5))
sns.set_style('darkgrid')
abc=df['City'].value_counts()[:10]
sns.barplot(x=abc,y=abc.index,palette='Set1')
plt.title("Top ten cities (sales wise)",size=20)
plt.xlabel("Number of orders",size=15)
# Out:
# Text(0.5, 0, 'Number of orders')

# %%
sns.set_context("poster", font_scale = 0.6, rc={"grid.linewidth": 5})
sns.set_style('darkgrid')
sns.catplot(x='Ship Mode', data=df,kind='count',height=4,aspect=1.5,palette='husl',).set_axis_labels('mode of shipping',
                                                                                                      'No. of orders')

# %%
sns.set_context("poster", font_scale = 0.6, rc={"grid.linewidth": 5})
sns.set_style('darkgrid')
sns.catplot(x='Segment', data=df,kind='count',height=4,aspect=1.5,palette='husl',).set_axis_labels('Segments',
                                                                                                      'No. of orders')

# %%
sns.set_context("poster", font_scale = 0.6, rc={"grid.linewidth": 5})
sns.set_style('darkgrid')
sns.catplot(x='Category', data=df,kind='count',height=4,aspect=1.5,
            palette='husl',).set_axis_labels('Category of order','no. of orders')

plt.figure(figsize=(15,5))
values=[6026,2121,1847]
labels= ['Office Supplies','Furniture','Technology']
plt.pie(values,labels=labels,autopct='%1.1f%%',counterclock=True)
plt.title('Categories of order')
plt.show()

# %%
sns.set_context("poster", font_scale = 0.6, rc={"grid.linewidth": 5})
sns.set_style('darkgrid')
sns.catplot(x='Sub-Category', data=df,kind='count',height=6.5,aspect=2.5,
            palette='husl',).set_axis_labels('Category of order','no. of orders')

# %%
plt.figure(figsize=(12,4))
sns.set_style('darkgrid')
abc=df[df['Category']=='Furniture']['Sub-Category'].value_counts()
sns.barplot(x=abc,y=abc.index,palette='Set1')
plt.title("Furniture sales",size=20)
plt.xlabel("Number of orders",size=15)
plt.ylabel("Items",size=15)

plt.figure(figsize=(12,5))
values=[957,617,319,228]
labels= ['Furnishings','Chairs','Tables','Bookcases']
plt.pie(values,labels=labels,autopct='%1.1f%%',counterclock=True)
plt.title('Categories of order')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.set_style('darkgrid')
abc=df[df['Category']=='Technology']['Sub-Category'].value_counts()
sns.barplot(x=abc,y=abc.index,palette='Set1')
plt.title("Technology sales",size=20)
plt.xlabel("Number of orders",size=15)
plt.ylabel("Items",size=15)

plt.figure(figsize=(12,5))
values=[889,775,115,68]
labels= ['Phones','Accessories','Machines','Copiers']
plt.pie(values,labels=labels,autopct='%1.1f%%',counterclock=True)
plt.title('Categories of order')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.set_style('darkgrid')
abc=df[df['Category']=='Office Supplies']['Sub-Category'].value_counts()
sns.barplot(x=abc,y=abc.index,palette='Set1')
plt.title("Ofiice Supply sales",size=20)
plt.xlabel("Number of orders",size=15)
plt.ylabel("Items",size=15)

plt.figure(figsize=(15,7))
values=[1523,1370,846,796,466,364,254,217,190]
labels= ['Biders','Paper','Storage','Art','Appliances','Labels','Envelops','Fasteners','Supplies']
plt.pie(values,labels=labels,autopct='%1.1f%%',counterclock=True)
plt.title('Categories of order')
plt.show()

# %%
plt.figure(figsize=(12,5))
values=[18451.2728,145454.9480999999,122490.80080000011]
labels= ['Furniture','Technology','Office supplies',]
colors = ['#ffff00','#3498DB','#239B56']
explode = (0.05,0.05,0.05)
plt.pie(values, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
plt.title('Total profit per Category')
plt.show()

# %%
plt.figure(figsize=(12,5))
values=[91522.78,108418.4489,39706.3625,46749.4303]
labels= ['East','West','Central','South']
colors = ['#ffff00','#239B56','#99ff99','#1e90ff']
explode = (0.05,0.05,0.05,0.05)
plt.pie(values, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
plt.title('Total profit per Region')
plt.show()

# %%
plt.figure(figsize=(20,16))
sns.barplot(x=df['Sub-Category'], y=df['Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %% [markdown]
# From above graph sales of bookcase and tables are but the profite is in negative in both cases. Company facing loss in these two products. Company have lots of profite in sale in copier but the number of sales is very less so their is need of increase number of sales os copier.

# %%
state = df.groupby("State")[["Sales","Profit"]].sum().sort_values(by = "Sales", ascending = False)
plt.figure(figsize = (30,30))
state[:25].plot(kind = "bar",color = ["green","yellow"],edgecolor = "#000000")
plt.title("Profit Or Loss & Sales of top 25 States")
plt.xlabel("States")
plt.ylabel("Total profit / loss and Sales")
plt.grid(True)
state[25:].plot(kind = "bar",color = ["green","yellow"],edgecolor = "#000000")
plt.title("Profit Or Loss & Sales of the least economic States")
plt.xlabel("States")
plt.ylabel("Total profit / loss and Sales")
plt.grid(True)

# %% [markdown]
# We can see that the company facing loss in top 25 states in compare to least economic states.

# %%
plt.figure(figsize=(12,6))
sns.lineplot('Discount','Profit',data=df,color='#17202A',label='Discount')
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# From the above study, when the profits of a state are compared with the discount provided in each state, the states which allowed more discount, went in loss and the above graph we conclude that THE PROFIT DECREASES WITH THE INCREASE IN DISCOUNT.

# %%
# Relationship between Sales and Profit
plt.figure(figsize=(10,5))
plt.scatter(df.Profit,df.Sales)
plt.xlabel('Profit',fontsize=12)
plt.xlabel('Sales',fontsize=12)
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
# 1.Most of the shipping is done in Standard class.
#
# 2.California State is dominant in terms of Business.
#
# 3.Most of the business happens in West region.
#
# 4.Company facing loss in these two products which are sales of bookcase and tables which are negative in both cases
#
# 5.Company have lots of profit in sale in copier but the number of sales is very less so there is need of increase number of sales of copier.
#
# 6.When the profits of a state are compared with the discount provided in each state, the states which has allowed more discount, went in loss.
#
# 7.In terms of category office supply has the most no. of sales.
#
# 8.Binders are highest in demand.
#
# 9.Office Supplies are excellent. We have to work more on Technology and Furniture Category of business.
